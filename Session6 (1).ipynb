# %%
import numpy as np
step = (np.pi * 2) / 1000
x = np.arange(0, 2 * np.pi, step)

# %% [markdown]
# Im important numpy so i can use it for cos and sin functions IM also setting up the x variable outside of the main function so its global same with step

# %%
def Sin(x):
    hold_sin = np.sin(x)
    return hold_sin

# %% [markdown]
# define functions sin(X) and returning it so it so you can see it

# %%
def Cos(x):
    hold_cos = np.cos(x)
    return hold_cos

# %% [markdown]
# define functions cos(x)

# %%
def main():
   for i in range(len(x)):
        print(f"Cos(x) Value:{Cos(x[i])} Sin(x) Value: {Sin(x[i])}")
if __name__ == "__main__":
    main()
# Out:
# X Value:1.0 Sin(x) Value: ('Sin(x)', 0.0)
# X Value:0.9999802608561372 Sin(x) Value: ('Sin(x)', 0.006283143965558951)
# X Value:0.9999210442038163 Sin(x) Value: ('Sin(x)', 0.012566039883352607)
# X Value:0.9998223523808092 Sin(x) Value: ('Sin(x)', 0.018848439715408175)
# X Value:0.9996841892833003 Sin(x) Value: ('Sin(x)', 0.02513009544333748)
# X Value:0.9995065603657317 Sin(x) Value: ('Sin(x)', 0.0314107590781283)
# X Value:0.9992894726405894 Sin(x) Value: ('Sin(x)', 0.03769018266993454)
# X Value:0.9990329346781248 Sin(x) Value: ('Sin(x)', 0.04396811831786491)
# X Value:0.9987369566060176 Sin(x) Value: ('Sin(x)', 0.050244318179769556)
# X Value:0.9984015501089751 Sin(x) Value: ('Sin(x)', 0.05651853448202453)
# X Value:0.9980267284282716 Sin(x) Value: ('Sin(x)', 0.06279051952931337)
# X Value:0.9976125063612251 Sin(x) Value: ('Sin(x)', 0.0690600257144058)
# X Value:0.9971589002606138 Sin(x) Value: ('Sin(x)', 0.07532680552793272)
# X Value:0.9966659280340299 Sin(x) Value: ('Sin(x)', 0.08159061156815756)
# X Value:0.9961336091431724 Sin(x) Value: ('Sin(x)', 0.08785119655074318)
# X Value:0.9955619646030798 Sin(x) Value: ('Sin(x)', 0.09410831331851433)
# X Value:0.9949510169813 Sin(x) Value: ('Sin(x)', 0.1003617148512149)
# X Value:0.9943007903969987 Sin(x) Value: ('Sin(x)', 0.10661115427525993)
# X Value:0.9936113105200082 Sin(x) Value: ('Sin(x)', 0.1128563848734817)
# X Value:0.9928826045698135 Sin(x) Value: ('Sin(x)', 0.11909716009486976)
# X Value:0.9921147013144777 Sin(x) Value: ('Sin(x)', 0.12533323356430426)
# X Value:0.9913076310695064 Sin(x) Value: ('Sin(x)', 0.1315643590922825)
# X Value:0.9904614256966511 Sin(x) Value: ('Sin(x)', 0.13779029068463808)
# X Value:0.9895761186026508 Sin(x) Value: ('Sin(x)', 0.14401078255225216)
# X Value:0.9886517447379138 Sin(x) Value: ('Sin(x)', 0.15022558912075706)
# X Value:0.9876883405951377 Sin(x) Value: ('Sin(x)', 0.15643446504023087)
# X Value:0.986685944207868 Sin(x) Value: ('Sin(x)', 0.1626371651948836)
# X Value:0.9856445951489979 Sin(x) Value: ('Sin(x)', 0.1688334447127339)
# X Value:0.9845643345292054 Sin(x) Value: ('Sin(x)', 0.1750230589752761)
# X Value:0.9834452049953297 Sin(x) Value: ('Sin(x)', 0.1812057636271374)
# X Value:0.9822872507286886 Sin(x) Value: ('Sin(x)', 0.18738131458572466)
# X Value:0.9810905174433341 Sin(x) Value: ('Sin(x)', 0.1935494680508603)
# X Value:0.979855052384247 Sin(x) Value: ('Sin(x)', 0.19970998051440705)
# X Value:0.9785809043254722 Sin(x) Value: ('Sin(x)', 0.20586260876988136)
# X Value:0.9772681235681935 Sin(x) Value: ('Sin(x)', 0.21200710992205468)
# X Value:0.9759167619387475 Sin(x) Value: ('Sin(x)', 0.2181432413965426)
# X Value:0.9745268727865772 Sin(x) Value: ('Sin(x)', 0.2242707609493812)
# X Value:0.9730985109821266 Sin(x) Value: ('Sin(x)', 0.23038942667659063)
# X Value:0.9716317329146741 Sin(x) Value: ('Sin(x)', 0.23649899702372473)
# X Value:0.9701265964901059 Sin(x) Value: ('Sin(x)', 0.2425992307954075)
# X Value:0.9685831611286313 Sin(x) Value: ('Sin(x)', 0.24868988716485485)
# X Value:0.9670014877624352 Sin(x) Value: ('Sin(x)', 0.2547707256833822)
# X Value:0.965381638833274 Sin(x) Value: ('Sin(x)', 0.260841506289897)
# X Value:0.9637236782900098 Sin(x) Value: ('Sin(x)', 0.2669019893203756)
# X Value:0.962027671586086 Sin(x) Value: ('Sin(x)', 0.2729519355173253)
# X Value:0.9602936856769432 Sin(x) Value: ('Sin(x)', 0.2789911060392293)
# X Value:0.9585217890173761 Sin(x) Value: ('Sin(x)', 0.28501926246997616)
# X Value:0.9567120515588305 Sin(x) Value: ('Sin(x)', 0.2910361668282719)
# X Value:0.9548645447466431 Sin(x) Value: ('Sin(x)', 0.297041581577035)
# X Value:0.9529793415172189 Sin(x) Value: ('Sin(x)', 0.303035269632774)
# X Value:0.9510565162951536 Sin(x) Value: ('Sin(x)', 0.30901699437494745)
# X Value:0.9490961449902946 Sin(x) Value: ('Sin(x)', 0.31498651965530483)
# X Value:0.9470983049947442 Sin(x) Value: ('Sin(x)', 0.32094360980720954)
# X Value:0.9450630751798049 Sin(x) Value: ('Sin(x)', 0.3268880296549425)
# X Value:0.9429905358928645 Sin(x) Value: ('Sin(x)', 0.33281954452298673)
# X Value:0.9408807689542255 Sin(x) Value: ('Sin(x)', 0.3387379202452915)
# X Value:0.938733857653874 Sin(x) Value: ('Sin(x)', 0.3446429231745171)
# X Value:0.9365498867481923 Sin(x) Value: ('Sin(x)', 0.3505343201912591)
# X Value:0.934328942456612 Sin(x) Value: ('Sin(x)', 0.35641187871325075)
# X Value:0.9320711124582108 Sin(x) Value: ('Sin(x)', 0.36227536670454574)
# X Value:0.9297764858882512 Sin(x) Value: ('Sin(x)', 0.36812455268467803)
# X Value:0.9274451533346612 Sin(x) Value: ('Sin(x)', 0.3739592057378005)
# X Value:0.9250772068344579 Sin(x) Value: ('Sin(x)', 0.37977909552180117)
# X Value:0.9226727398701147 Sin(x) Value: ('Sin(x)', 0.3855839922773966)
# X Value:0.9202318473658702 Sin(x) Value: ('Sin(x)', 0.3913736668372024)
# X Value:0.917754625683981 Sin(x) Value: ('Sin(x)', 0.3971478906347806)
# X Value:0.9152411726209174 Sin(x) Value: ('Sin(x)', 0.4029064357136627)
# X Value:0.9126915874035026 Sin(x) Value: ('Sin(x)', 0.40864907473634904)
# X Value:0.9101059706849954 Sin(x) Value: ('Sin(x)', 0.41437558099328414)
# X Value:0.9074844245411167 Sin(x) Value: ('Sin(x)', 0.42008572841180625)
# X Value:0.9048270524660194 Sin(x) Value: ('Sin(x)', 0.42577929156507266)
# X Value:0.9021339593682026 Sin(x) Value: ('Sin(x)', 0.43145604568095897)
# X Value:0.8994052515663709 Sin(x) Value: ('Sin(x)', 0.4371157666509329)
# X Value:0.8966410367852358 Sin(x) Value: ('Sin(x)', 0.4427582310389015)
# X Value:0.8938414241512637 Sin(x) Value: ('Sin(x)', 0.44838321609003223)
# X Value:0.8910065241883677 Sin(x) Value: ('Sin(x)', 0.4539904997395468)
# X Value:0.8881364488135444 Sin(x) Value: ('Sin(x)', 0.45957986062148787)
# X Value:0.885231311332455 Sin(x) Value: ('Sin(x)', 0.46515107807745837)
# X Value:0.8822912264349531 Sin(x) Value: ('Sin(x)', 0.4707039321653326)
# X Value:0.8793163101905561 Sin(x) Value: ('Sin(x)', 0.4762382036679391)
# X Value:0.8763066800438635 Sin(x) Value: ('Sin(x)', 0.48175367410171527)
# X Value:0.8732624548099202 Sin(x) Value: ('Sin(x)', 0.4872501257253322)
# X Value:0.8701837546695256 Sin(x) Value: ('Sin(x)', 0.4927273415482915)
# X Value:0.86707070116449 Sin(x) Value: ('Sin(x)', 0.49818510533949073)
# X Value:0.8639234171928353 Sin(x) Value: ('Sin(x)', 0.5036232016357608)
# X Value:0.8607420270039435 Sin(x) Value: ('Sin(x)', 0.5090414157503712)
# X Value:0.8575266561936521 Sin(x) Value: ('Sin(x)', 0.5144395337815064)
# X Value:0.854277431699295 Sin(x) Value: ('Sin(x)', 0.5198173426207094)
# X Value:0.8509944817946918 Sin(x) Value: ('Sin(x)', 0.5251746299612956)
# X Value:0.8476779360850831 Sin(x) Value: ('Sin(x)', 0.530511184306734)
# X Value:0.8443279255020151 Sin(x) Value: ('Sin(x)', 0.5358267949789965)
# X Value:0.840944582298169 Sin(x) Value: ('Sin(x)', 0.5411212521268758)
# X Value:0.8375280400421418 Sin(x) Value: ('Sin(x)', 0.546394346734269)
# X Value:0.8340784336131712 Sin(x) Value: ('Sin(x)', 0.5516458706284302)
# X Value:0.8305958991958127 Sin(x) Value: ('Sin(x)', 0.556875616488188)
# X Value:0.8270805742745618 Sin(x) Value: ('Sin(x)', 0.5620833778521306)
# X Value:0.8235325976284276 Sin(x) Value: ('Sin(x)', 0.5672689491267564)
# X Value:0.8199521093254524 Sin(x) Value: ('Sin(x)', 0.5724321255945908)
# X Value:0.816339250717184 Sin(x) Value: ('Sin(x)', 0.5775727034222675)
# X Value:0.8126941644330941 Sin(x) Value: ('Sin(x)', 0.582690479668576)
# X Value:0.8090169943749476 Sin(x) Value: ('Sin(x)', 0.587785252292473)
# X Value:0.8053078857111221 Sin(x) Value: ('Sin(x)', 0.5928568201610592)
# X Value:0.8015669848708767 Sin(x) Value: ('Sin(x)', 0.5979049830575188)
# X Value:0.7977944395385711 Sin(x) Value: ('Sin(x)', 0.6029295416890247)
# X Value:0.7939903986478355 Sin(x) Value: ('Sin(x)', 0.6079302976946053)
# X Value:0.7901550123756905 Sin(x) Value: ('Sin(x)', 0.6129070536529765)
# X Value:0.786288432136619 Sin(x) Value: ('Sin(x)', 0.6178596130903342)
# X Value:0.7823908105765882 Sin(x) Value: ('Sin(x)', 0.6227877804881125)
# X Value:0.7784623015670236 Sin(x) Value: ('Sin(x)', 0.6276913612907005)
# X Value:0.7745030601987339 Sin(x) Value: ('Sin(x)', 0.6325701619131244)
# X Value:0.7705132427757894 Sin(x) Value: ('Sin(x)', 0.6374239897486897)
# X Value:0.76649300680935 Sin(x) Value: ('Sin(x)', 0.6422526531765843)
# X Value:0.762442511011448 Sin(x) Value: ('Sin(x)', 0.6470559615694443)
# X Value:0.758361915288722 Sin(x) Value: ('Sin(x)', 0.6518337253008787)
# X Value:0.7542513807361039 Sin(x) Value: ('Sin(x)', 0.6565857557529564)
# X Value:0.7501110696304597 Sin(x) Value: ('Sin(x)', 0.6613118653236518)
# X Value:0.7459411454241822 Sin(x) Value: ('Sin(x)', 0.6660118674342517)
# X Value:0.7417417727387393 Sin(x) Value: ('Sin(x)', 0.67068557653672)
# X Value:0.737513117358174 Sin(x) Value: ('Sin(x)', 0.6753328081210245)
# X Value:0.7332553462225602 Sin(x) Value: ('Sin(x)', 0.6799533787224192)
# X Value:0.7289686274214117 Sin(x) Value: ('Sin(x)', 0.6845471059286887)
# X Value:0.7246531301870468 Sin(x) Value: ('Sin(x)', 0.6891138083873485)
# X Value:0.7203090248879069 Sin(x) Value: ('Sin(x)', 0.693653305812805)
# X Value:0.7159364830218313 Sin(x) Value: ('Sin(x)', 0.6981654189934727)
# X Value:0.7115356772092855 Sin(x) Value: ('Sin(x)', 0.7026499697988493)
# X Value:0.7071067811865477 Sin(x) Value: ('Sin(x)', 0.7071067811865476)
# X Value:0.7026499697988493 Sin(x) Value: ('Sin(x)', 0.7115356772092855)
# X Value:0.6981654189934727 Sin(x) Value: ('Sin(x)', 0.7159364830218312)
# X Value:0.693653305812805 Sin(x) Value: ('Sin(x)', 0.7203090248879069)
# X Value:0.6891138083873485 Sin(x) Value: ('Sin(x)', 0.7246531301870468)
# X Value:0.6845471059286887 Sin(x) Value: ('Sin(x)', 0.7289686274214117)
# X Value:0.6799533787224192 Sin(x) Value: ('Sin(x)', 0.7332553462225602)
# X Value:0.6753328081210245 Sin(x) Value: ('Sin(x)', 0.737513117358174)
# X Value:0.67068557653672 Sin(x) Value: ('Sin(x)', 0.7417417727387393)
# X Value:0.6660118674342517 Sin(x) Value: ('Sin(x)', 0.7459411454241822)
# X Value:0.6613118653236518 Sin(x) Value: ('Sin(x)', 0.7501110696304597)
# X Value:0.6565857557529564 Sin(x) Value: ('Sin(x)', 0.754251380736104)
# X Value:0.6518337253008787 Sin(x) Value: ('Sin(x)', 0.758361915288722)
# X Value:0.6470559615694443 Sin(x) Value: ('Sin(x)', 0.762442511011448)
# X Value:0.6422526531765843 Sin(x) Value: ('Sin(x)', 0.76649300680935)
# X Value:0.6374239897486897 Sin(x) Value: ('Sin(x)', 0.7705132427757894)
# X Value:0.6325701619131244 Sin(x) Value: ('Sin(x)', 0.7745030601987339)
# X Value:0.6276913612907005 Sin(x) Value: ('Sin(x)', 0.7784623015670236)
# X Value:0.6227877804881125 Sin(x) Value: ('Sin(x)', 0.7823908105765883)
# X Value:0.6178596130903343 Sin(x) Value: ('Sin(x)', 0.786288432136619)
# X Value:0.6129070536529764 Sin(x) Value: ('Sin(x)', 0.7901550123756905)
# X Value:0.6079302976946054 Sin(x) Value: ('Sin(x)', 0.7939903986478354)
# X Value:0.6029295416890247 Sin(x) Value: ('Sin(x)', 0.7977944395385711)
# X Value:0.5979049830575188 Sin(x) Value: ('Sin(x)', 0.8015669848708766)
# X Value:0.5928568201610592 Sin(x) Value: ('Sin(x)', 0.8053078857111221)
# X Value:0.587785252292473 Sin(x) Value: ('Sin(x)', 0.8090169943749476)
# X Value:0.582690479668576 Sin(x) Value: ('Sin(x)', 0.8126941644330941)
# X Value:0.5775727034222675 Sin(x) Value: ('Sin(x)', 0.816339250717184)
# X Value:0.5724321255945908 Sin(x) Value: ('Sin(x)', 0.8199521093254524)
# X Value:0.5672689491267564 Sin(x) Value: ('Sin(x)', 0.8235325976284276)
# X Value:0.5620833778521306 Sin(x) Value: ('Sin(x)', 0.8270805742745619)
# X Value:0.556875616488188 Sin(x) Value: ('Sin(x)', 0.8305958991958128)
# X Value:0.5516458706284302 Sin(x) Value: ('Sin(x)', 0.8340784336131712)
# X Value:0.546394346734269 Sin(x) Value: ('Sin(x)', 0.8375280400421418)
# X Value:0.5411212521268758 Sin(x) Value: ('Sin(x)', 0.840944582298169)
# X Value:0.5358267949789965 Sin(x) Value: ('Sin(x)', 0.8443279255020151)
# X Value:0.5305111843067339 Sin(x) Value: ('Sin(x)', 0.8476779360850834)
# X Value:0.5251746299612957 Sin(x) Value: ('Sin(x)', 0.8509944817946918)
# X Value:0.5198173426207094 Sin(x) Value: ('Sin(x)', 0.8542774316992952)
# X Value:0.5144395337815064 Sin(x) Value: ('Sin(x)', 0.8575266561936522)
# X Value:0.5090414157503712 Sin(x) Value: ('Sin(x)', 0.8607420270039436)
# X Value:0.5036232016357609 Sin(x) Value: ('Sin(x)', 0.8639234171928353)
# X Value:0.49818510533949084 Sin(x) Value: ('Sin(x)', 0.86707070116449)
# X Value:0.4927273415482915 Sin(x) Value: ('Sin(x)', 0.8701837546695256)
# X Value:0.4872501257253322 Sin(x) Value: ('Sin(x)', 0.8732624548099202)
# X Value:0.4817536741017154 Sin(x) Value: ('Sin(x)', 0.8763066800438635)
# X Value:0.4762382036679391 Sin(x) Value: ('Sin(x)', 0.8793163101905561)
# X Value:0.4707039321653325 Sin(x) Value: ('Sin(x)', 0.8822912264349532)
# X Value:0.46515107807745826 Sin(x) Value: ('Sin(x)', 0.8852313113324551)
# X Value:0.4595798606214877 Sin(x) Value: ('Sin(x)', 0.8881364488135445)
# X Value:0.4539904997395468 Sin(x) Value: ('Sin(x)', 0.8910065241883677)
# X Value:0.44838321609003223 Sin(x) Value: ('Sin(x)', 0.8938414241512637)
# X Value:0.44275823103890144 Sin(x) Value: ('Sin(x)', 0.8966410367852358)
# X Value:0.43711576665093277 Sin(x) Value: ('Sin(x)', 0.899405251566371)
# X Value:0.431456045680959 Sin(x) Value: ('Sin(x)', 0.9021339593682026)
# X Value:0.42577929156507266 Sin(x) Value: ('Sin(x)', 0.9048270524660195)
# X Value:0.4200857284118062 Sin(x) Value: ('Sin(x)', 0.9074844245411168)
# X Value:0.41437558099328403 Sin(x) Value: ('Sin(x)', 0.9101059706849957)
# X Value:0.4086490747363491 Sin(x) Value: ('Sin(x)', 0.9126915874035026)
# X Value:0.4029064357136627 Sin(x) Value: ('Sin(x)', 0.9152411726209174)
# X Value:0.39714789063478056 Sin(x) Value: ('Sin(x)', 0.917754625683981)
# X Value:0.39137366683720237 Sin(x) Value: ('Sin(x)', 0.9202318473658703)
# X Value:0.38558399227739665 Sin(x) Value: ('Sin(x)', 0.9226727398701147)
# X Value:0.37977909552180117 Sin(x) Value: ('Sin(x)', 0.9250772068344579)
# X Value:0.37395920573780045 Sin(x) Value: ('Sin(x)', 0.9274451533346613)
# X Value:0.3681245526846779 Sin(x) Value: ('Sin(x)', 0.9297764858882515)
# X Value:0.3622753667045458 Sin(x) Value: ('Sin(x)', 0.9320711124582108)
# X Value:0.35641187871325075 Sin(x) Value: ('Sin(x)', 0.934328942456612)
# X Value:0.350534320191259 Sin(x) Value: ('Sin(x)', 0.9365498867481924)
# X Value:0.344642923174517 Sin(x) Value: ('Sin(x)', 0.9387338576538742)
# X Value:0.3387379202452913 Sin(x) Value: ('Sin(x)', 0.9408807689542256)
# X Value:0.33281954452298673 Sin(x) Value: ('Sin(x)', 0.9429905358928645)
# X Value:0.3268880296549425 Sin(x) Value: ('Sin(x)', 0.9450630751798049)
# X Value:0.3209436098072095 Sin(x) Value: ('Sin(x)', 0.9470983049947443)
# X Value:0.3149865196553047 Sin(x) Value: ('Sin(x)', 0.9490961449902947)
# X Value:0.3090169943749475 Sin(x) Value: ('Sin(x)', 0.9510565162951536)
# X Value:0.303035269632774 Sin(x) Value: ('Sin(x)', 0.9529793415172189)
# X Value:0.2970415815770349 Sin(x) Value: ('Sin(x)', 0.9548645447466431)
# X Value:0.29103616682827177 Sin(x) Value: ('Sin(x)', 0.9567120515588307)
# X Value:0.2850192624699762 Sin(x) Value: ('Sin(x)', 0.9585217890173761)
# X Value:0.2789911060392293 Sin(x) Value: ('Sin(x)', 0.9602936856769432)
# X Value:0.2729519355173252 Sin(x) Value: ('Sin(x)', 0.962027671586086)
# X Value:0.2669019893203755 Sin(x) Value: ('Sin(x)', 0.9637236782900099)
# X Value:0.26084150628989705 Sin(x) Value: ('Sin(x)', 0.9653816388332741)
# X Value:0.2547707256833822 Sin(x) Value: ('Sin(x)', 0.9670014877624352)
# X Value:0.2486898871648548 Sin(x) Value: ('Sin(x)', 0.9685831611286313)
# X Value:0.24259923079540738 Sin(x) Value: ('Sin(x)', 0.970126596490106)
# X Value:0.2364989970237248 Sin(x) Value: ('Sin(x)', 0.9716317329146741)
# X Value:0.23038942667659065 Sin(x) Value: ('Sin(x)', 0.9730985109821266)
# X Value:0.2242707609493812 Sin(x) Value: ('Sin(x)', 0.9745268727865772)
# X Value:0.2181432413965425 Sin(x) Value: ('Sin(x)', 0.9759167619387475)
# X Value:0.21200710992205454 Sin(x) Value: ('Sin(x)', 0.9772681235681936)
# X Value:0.20586260876988138 Sin(x) Value: ('Sin(x)', 0.9785809043254722)
# X Value:0.19970998051440703 Sin(x) Value: ('Sin(x)', 0.979855052384247)
# X Value:0.1935494680508602 Sin(x) Value: ('Sin(x)', 0.9810905174433342)
# X Value:0.18738131458572452 Sin(x) Value: ('Sin(x)', 0.9822872507286887)
# X Value:0.18120576362713742 Sin(x) Value: ('Sin(x)', 0.9834452049953297)
# X Value:0.17502305897527606 Sin(x) Value: ('Sin(x)', 0.9845643345292054)
# X Value:0.16883344471273382 Sin(x) Value: ('Sin(x)', 0.9856445951489979)
# X Value:0.1626371651948835 Sin(x) Value: ('Sin(x)', 0.986685944207868)
# X Value:0.15643446504023092 Sin(x) Value: ('Sin(x)', 0.9876883405951377)
# X Value:0.15022558912075706 Sin(x) Value: ('Sin(x)', 0.988651744737914)
# X Value:0.1440107825522521 Sin(x) Value: ('Sin(x)', 0.9895761186026509)
# X Value:0.13779029068463797 Sin(x) Value: ('Sin(x)', 0.9904614256966511)
# X Value:0.13156435909228256 Sin(x) Value: ('Sin(x)', 0.9913076310695065)
# X Value:0.12533323356430426 Sin(x) Value: ('Sin(x)', 0.9921147013144777)
# X Value:0.1190971600948697 Sin(x) Value: ('Sin(x)', 0.9928826045698136)
# X Value:0.1128563848734816 Sin(x) Value: ('Sin(x)', 0.9936113105200083)
# X Value:0.10661115427525998 Sin(x) Value: ('Sin(x)', 0.9943007903969988)
# X Value:0.10036171485121491 Sin(x) Value: ('Sin(x)', 0.9949510169813001)
# X Value:0.09410831331851428 Sin(x) Value: ('Sin(x)', 0.9955619646030799)
# X Value:0.08785119655074308 Sin(x) Value: ('Sin(x)', 0.9961336091431724)
# X Value:0.08159061156815742 Sin(x) Value: ('Sin(x)', 0.9966659280340298)
# X Value:0.07532680552793275 Sin(x) Value: ('Sin(x)', 0.9971589002606138)
# X Value:0.06906002571440577 Sin(x) Value: ('Sin(x)', 0.9976125063612252)
# X Value:0.06279051952931329 Sin(x) Value: ('Sin(x)', 0.9980267284282717)
# X Value:0.0565185344820244 Sin(x) Value: ('Sin(x)', 0.998401550108975)
# X Value:0.0502443181797696 Sin(x) Value: ('Sin(x)', 0.9987369566060176)
# X Value:0.043968118317864895 Sin(x) Value: ('Sin(x)', 0.9990329346781248)
# X Value:0.03769018266993448 Sin(x) Value: ('Sin(x)', 0.9992894726405894)
# X Value:0.03141075907812818 Sin(x) Value: ('Sin(x)', 0.9995065603657317)
# X Value:0.02513009544333753 Sin(x) Value: ('Sin(x)', 0.9996841892833002)
# X Value:0.018848439715408175 Sin(x) Value: ('Sin(x)', 0.9998223523808092)
# X Value:0.012566039883352552 Sin(x) Value: ('Sin(x)', 0.9999210442038162)
# X Value:0.0062831439655588435 Sin(x) Value: ('Sin(x)', 0.9999802608561371)
# X Value:6.123233995736766e-17 Sin(x) Value: ('Sin(x)', 1.0)
# X Value:-0.006283143965558942 Sin(x) Value: ('Sin(x)', 0.9999802608561371)
# X Value:-0.012566039883352653 Sin(x) Value: ('Sin(x)', 0.9999210442038162)
# X Value:-0.018848439715408272 Sin(x) Value: ('Sin(x)', 0.9998223523808092)
# X Value:-0.025130095443337407 Sin(x) Value: ('Sin(x)', 0.9996841892833002)
# X Value:-0.03141075907812828 Sin(x) Value: ('Sin(x)', 0.9995065603657317)
# X Value:-0.037690182669934576 Sin(x) Value: ('Sin(x)', 0.9992894726405894)
# X Value:-0.04396811831786499 Sin(x) Value: ('Sin(x)', 0.9990329346781248)
# X Value:-0.050244318179769695 Sin(x) Value: ('Sin(x)', 0.9987369566060176)
# X Value:-0.0565185344820245 Sin(x) Value: ('Sin(x)', 0.998401550108975)
# X Value:-0.0627905195293134 Sin(x) Value: ('Sin(x)', 0.9980267284282717)
# X Value:-0.06906002571440588 Sin(x) Value: ('Sin(x)', 0.9976125063612252)
# X Value:-0.07532680552793286 Sin(x) Value: ('Sin(x)', 0.9971589002606138)
# X Value:-0.08159061156815753 Sin(x) Value: ('Sin(x)', 0.9966659280340298)
# X Value:-0.0878511965507432 Sin(x) Value: ('Sin(x)', 0.9961336091431724)
# X Value:-0.0941083133185144 Sin(x) Value: ('Sin(x)', 0.9955619646030799)
# X Value:-0.10036171485121502 Sin(x) Value: ('Sin(x)', 0.9949510169813001)
# X Value:-0.10661115427525988 Sin(x) Value: ('Sin(x)', 0.9943007903969988)
# X Value:-0.11285638487348171 Sin(x) Value: ('Sin(x)', 0.9936113105200083)
# X Value:-0.11909716009486981 Sin(x) Value: ('Sin(x)', 0.9928826045698136)
# X Value:-0.12533323356430437 Sin(x) Value: ('Sin(x)', 0.9921147013144777)
# X Value:-0.13156435909228245 Sin(x) Value: ('Sin(x)', 0.9913076310695065)
# X Value:-0.13779029068463808 Sin(x) Value: ('Sin(x)', 0.9904614256966511)
# X Value:-0.14401078255225222 Sin(x) Value: ('Sin(x)', 0.9895761186026509)
# X Value:-0.15022558912075717 Sin(x) Value: ('Sin(x)', 0.988651744737914)
# X Value:-0.1564344650402308 Sin(x) Value: ('Sin(x)', 0.9876883405951377)
# X Value:-0.1626371651948836 Sin(x) Value: ('Sin(x)', 0.986685944207868)
# X Value:-0.16883344471273393 Sin(x) Value: ('Sin(x)', 0.9856445951489979)
# X Value:-0.17502305897527617 Sin(x) Value: ('Sin(x)', 0.9845643345292054)
# X Value:-0.18120576362713753 Sin(x) Value: ('Sin(x)', 0.9834452049953297)
# X Value:-0.18738131458572463 Sin(x) Value: ('Sin(x)', 0.9822872507286887)
# X Value:-0.19354946805086032 Sin(x) Value: ('Sin(x)', 0.9810905174433342)
# X Value:-0.19970998051440714 Sin(x) Value: ('Sin(x)', 0.979855052384247)
# X Value:-0.2058626087698815 Sin(x) Value: ('Sin(x)', 0.9785809043254722)
# X Value:-0.21200710992205465 Sin(x) Value: ('Sin(x)', 0.9772681235681936)
# X Value:-0.21814324139654262 Sin(x) Value: ('Sin(x)', 0.9759167619387475)
# X Value:-0.22427076094938128 Sin(x) Value: ('Sin(x)', 0.9745268727865772)
# X Value:-0.23038942667659074 Sin(x) Value: ('Sin(x)', 0.9730985109821266)
# X Value:-0.23649899702372468 Sin(x) Value: ('Sin(x)', 0.9716317329146741)
# X Value:-0.2425992307954075 Sin(x) Value: ('Sin(x)', 0.970126596490106)
# X Value:-0.2486898871648549 Sin(x) Value: ('Sin(x)', 0.9685831611286313)
# X Value:-0.2547707256833823 Sin(x) Value: ('Sin(x)', 0.9670014877624352)
# X Value:-0.26084150628989694 Sin(x) Value: ('Sin(x)', 0.9653816388332741)
# X Value:-0.2669019893203756 Sin(x) Value: ('Sin(x)', 0.9637236782900099)
# X Value:-0.27295193551732533 Sin(x) Value: ('Sin(x)', 0.962027671586086)
# X Value:-0.2789911060392294 Sin(x) Value: ('Sin(x)', 0.9602936856769432)
# X Value:-0.2850192624699761 Sin(x) Value: ('Sin(x)', 0.9585217890173761)
# X Value:-0.2910361668282719 Sin(x) Value: ('Sin(x)', 0.9567120515588307)
# X Value:-0.29704158157703503 Sin(x) Value: ('Sin(x)', 0.9548645447466431)
# X Value:-0.3030352696327741 Sin(x) Value: ('Sin(x)', 0.9529793415172189)
# X Value:-0.3090169943749476 Sin(x) Value: ('Sin(x)', 0.9510565162951536)
# X Value:-0.31498651965530483 Sin(x) Value: ('Sin(x)', 0.9490961449902947)
# X Value:-0.3209436098072096 Sin(x) Value: ('Sin(x)', 0.9470983049947443)
# X Value:-0.3268880296549426 Sin(x) Value: ('Sin(x)', 0.9450630751798049)
# X Value:-0.33281954452298684 Sin(x) Value: ('Sin(x)', 0.9429905358928645)
# X Value:-0.3387379202452914 Sin(x) Value: ('Sin(x)', 0.9408807689542256)
# X Value:-0.3446429231745171 Sin(x) Value: ('Sin(x)', 0.9387338576538742)
# X Value:-0.35053432019125913 Sin(x) Value: ('Sin(x)', 0.9365498867481924)
# X Value:-0.35641187871325086 Sin(x) Value: ('Sin(x)', 0.934328942456612)
# X Value:-0.3622753667045457 Sin(x) Value: ('Sin(x)', 0.932071112458211)
# X Value:-0.36812455268467803 Sin(x) Value: ('Sin(x)', 0.9297764858882515)
# X Value:-0.37395920573780056 Sin(x) Value: ('Sin(x)', 0.9274451533346613)
# X Value:-0.3797790955218012 Sin(x) Value: ('Sin(x)', 0.9250772068344579)
# X Value:-0.38558399227739654 Sin(x) Value: ('Sin(x)', 0.9226727398701148)
# X Value:-0.3913736668372024 Sin(x) Value: ('Sin(x)', 0.9202318473658703)
# X Value:-0.3971478906347807 Sin(x) Value: ('Sin(x)', 0.917754625683981)
# X Value:-0.4029064357136628 Sin(x) Value: ('Sin(x)', 0.9152411726209174)
# X Value:-0.40864907473634904 Sin(x) Value: ('Sin(x)', 0.9126915874035028)
# X Value:-0.41437558099328414 Sin(x) Value: ('Sin(x)', 0.9101059706849957)
# X Value:-0.4200857284118063 Sin(x) Value: ('Sin(x)', 0.9074844245411168)
# X Value:-0.42577929156507277 Sin(x) Value: ('Sin(x)', 0.9048270524660195)
# X Value:-0.43145604568095913 Sin(x) Value: ('Sin(x)', 0.9021339593682026)
# X Value:-0.4371157666509331 Sin(x) Value: ('Sin(x)', 0.8994052515663709)
# X Value:-0.4427582310389018 Sin(x) Value: ('Sin(x)', 0.8966410367852357)
# X Value:-0.4483832160900321 Sin(x) Value: ('Sin(x)', 0.8938414241512638)
# X Value:-0.4539904997395467 Sin(x) Value: ('Sin(x)', 0.8910065241883678)
# X Value:-0.4595798606214878 Sin(x) Value: ('Sin(x)', 0.8881364488135445)
# X Value:-0.46515107807745837 Sin(x) Value: ('Sin(x)', 0.8852313113324551)
# X Value:-0.47070393216533263 Sin(x) Value: ('Sin(x)', 0.8822912264349532)
# X Value:-0.4762382036679392 Sin(x) Value: ('Sin(x)', 0.8793163101905561)
# X Value:-0.4817536741017154 Sin(x) Value: ('Sin(x)', 0.8763066800438635)
# X Value:-0.48725012572533244 Sin(x) Value: ('Sin(x)', 0.87326245480992)
# X Value:-0.49272734154829134 Sin(x) Value: ('Sin(x)', 0.8701837546695257)
# X Value:-0.4981851053394907 Sin(x) Value: ('Sin(x)', 0.8670707011644901)
# X Value:-0.5036232016357607 Sin(x) Value: ('Sin(x)', 0.8639234171928354)
# X Value:-0.5090414157503712 Sin(x) Value: ('Sin(x)', 0.8607420270039436)
# X Value:-0.5144395337815064 Sin(x) Value: ('Sin(x)', 0.8575266561936522)
# X Value:-0.5198173426207094 Sin(x) Value: ('Sin(x)', 0.8542774316992952)
# X Value:-0.5251746299612957 Sin(x) Value: ('Sin(x)', 0.8509944817946918)
# X Value:-0.5305111843067342 Sin(x) Value: ('Sin(x)', 0.8476779360850831)
# X Value:-0.5358267949789963 Sin(x) Value: ('Sin(x)', 0.8443279255020153)
# X Value:-0.5411212521268756 Sin(x) Value: ('Sin(x)', 0.8409445822981692)
# X Value:-0.5463943467342689 Sin(x) Value: ('Sin(x)', 0.8375280400421418)
# X Value:-0.5516458706284301 Sin(x) Value: ('Sin(x)', 0.8340784336131712)
# X Value:-0.556875616488188 Sin(x) Value: ('Sin(x)', 0.8305958991958127)
# X Value:-0.5620833778521306 Sin(x) Value: ('Sin(x)', 0.8270805742745618)
# X Value:-0.5672689491267565 Sin(x) Value: ('Sin(x)', 0.8235325976284275)
# X Value:-0.5724321255945909 Sin(x) Value: ('Sin(x)', 0.8199521093254523)
# X Value:-0.5775727034222676 Sin(x) Value: ('Sin(x)', 0.8163392507171839)
# X Value:-0.5826904796685758 Sin(x) Value: ('Sin(x)', 0.8126941644330942)
# X Value:-0.5877852522924729 Sin(x) Value: ('Sin(x)', 0.8090169943749476)
# X Value:-0.5928568201610591 Sin(x) Value: ('Sin(x)', 0.8053078857111221)
# X Value:-0.5979049830575188 Sin(x) Value: ('Sin(x)', 0.8015669848708766)
# X Value:-0.6029295416890247 Sin(x) Value: ('Sin(x)', 0.7977944395385711)
# X Value:-0.6079302976946054 Sin(x) Value: ('Sin(x)', 0.7939903986478354)
# X Value:-0.6129070536529765 Sin(x) Value: ('Sin(x)', 0.7901550123756903)
# X Value:-0.6178596130903344 Sin(x) Value: ('Sin(x)', 0.7862884321366189)
# X Value:-0.6227877804881122 Sin(x) Value: ('Sin(x)', 0.7823908105765883)
# X Value:-0.6276913612907002 Sin(x) Value: ('Sin(x)', 0.7784623015670236)
# X Value:-0.6325701619131243 Sin(x) Value: ('Sin(x)', 0.7745030601987339)
# X Value:-0.6374239897486896 Sin(x) Value: ('Sin(x)', 0.7705132427757894)
# X Value:-0.6422526531765843 Sin(x) Value: ('Sin(x)', 0.76649300680935)
# X Value:-0.6470559615694443 Sin(x) Value: ('Sin(x)', 0.7624425110114479)
# X Value:-0.6518337253008788 Sin(x) Value: ('Sin(x)', 0.7583619152887219)
# X Value:-0.6565857557529565 Sin(x) Value: ('Sin(x)', 0.7542513807361038)
# X Value:-0.661311865323652 Sin(x) Value: ('Sin(x)', 0.7501110696304595)
# X Value:-0.6660118674342514 Sin(x) Value: ('Sin(x)', 0.7459411454241823)
# X Value:-0.6706855765367199 Sin(x) Value: ('Sin(x)', 0.7417417727387393)
# X Value:-0.6753328081210244 Sin(x) Value: ('Sin(x)', 0.737513117358174)
# X Value:-0.6799533787224192 Sin(x) Value: ('Sin(x)', 0.7332553462225601)
# X Value:-0.6845471059286887 Sin(x) Value: ('Sin(x)', 0.7289686274214116)
# X Value:-0.6891138083873486 Sin(x) Value: ('Sin(x)', 0.7246531301870466)
# X Value:-0.693653305812805 Sin(x) Value: ('Sin(x)', 0.7203090248879068)
# X Value:-0.6981654189934728 Sin(x) Value: ('Sin(x)', 0.715936483021831)
# X Value:-0.7026499697988491 Sin(x) Value: ('Sin(x)', 0.7115356772092855)
# X Value:-0.7071067811865475 Sin(x) Value: ('Sin(x)', 0.7071067811865477)
# X Value:-0.7115356772092853 Sin(x) Value: ('Sin(x)', 0.7026499697988493)
# X Value:-0.7159364830218312 Sin(x) Value: ('Sin(x)', 0.6981654189934727)
# X Value:-0.7203090248879069 Sin(x) Value: ('Sin(x)', 0.6936533058128049)
# X Value:-0.7246531301870468 Sin(x) Value: ('Sin(x)', 0.6891138083873484)
# X Value:-0.7289686274214117 Sin(x) Value: ('Sin(x)', 0.6845471059286886)
# X Value:-0.7332553462225603 Sin(x) Value: ('Sin(x)', 0.679953378722419)
# X Value:-0.7375131173581738 Sin(x) Value: ('Sin(x)', 0.6753328081210246)
# X Value:-0.7417417727387392 Sin(x) Value: ('Sin(x)', 0.6706855765367201)
# X Value:-0.7459411454241822 Sin(x) Value: ('Sin(x)', 0.6660118674342517)
# X Value:-0.7501110696304596 Sin(x) Value: ('Sin(x)', 0.6613118653236518)
# X Value:-0.7542513807361039 Sin(x) Value: ('Sin(x)', 0.6565857557529564)
# X Value:-0.758361915288722 Sin(x) Value: ('Sin(x)', 0.6518337253008787)
# X Value:-0.762442511011448 Sin(x) Value: ('Sin(x)', 0.6470559615694441)
# X Value:-0.7664930068093501 Sin(x) Value: ('Sin(x)', 0.6422526531765842)
# X Value:-0.7705132427757895 Sin(x) Value: ('Sin(x)', 0.6374239897486894)
# X Value:-0.7745030601987338 Sin(x) Value: ('Sin(x)', 0.6325701619131245)
# X Value:-0.7784623015670235 Sin(x) Value: ('Sin(x)', 0.6276913612907005)
# X Value:-0.7823908105765882 Sin(x) Value: ('Sin(x)', 0.6227877804881125)
# X Value:-0.786288432136619 Sin(x) Value: ('Sin(x)', 0.6178596130903342)
# X Value:-0.7901550123756905 Sin(x) Value: ('Sin(x)', 0.6129070536529764)
# X Value:-0.7939903986478355 Sin(x) Value: ('Sin(x)', 0.6079302976946052)
# X Value:-0.7977944395385712 Sin(x) Value: ('Sin(x)', 0.6029295416890245)
# X Value:-0.8015669848708767 Sin(x) Value: ('Sin(x)', 0.5979049830575186)
# X Value:-0.805307885711122 Sin(x) Value: ('Sin(x)', 0.5928568201610592)
# X Value:-0.8090169943749475 Sin(x) Value: ('Sin(x)', 0.5877852522924731)
# X Value:-0.812694164433094 Sin(x) Value: ('Sin(x)', 0.582690479668576)
# X Value:-0.816339250717184 Sin(x) Value: ('Sin(x)', 0.5775727034222675)
# X Value:-0.8199521093254524 Sin(x) Value: ('Sin(x)', 0.5724321255945908)
# X Value:-0.8235325976284276 Sin(x) Value: ('Sin(x)', 0.5672689491267563)
# X Value:-0.8270805742745619 Sin(x) Value: ('Sin(x)', 0.5620833778521304)
# X Value:-0.8305958991958128 Sin(x) Value: ('Sin(x)', 0.5568756164881877)
# X Value:-0.8340784336131714 Sin(x) Value: ('Sin(x)', 0.55164587062843)
# X Value:-0.8375280400421417 Sin(x) Value: ('Sin(x)', 0.5463943467342691)
# X Value:-0.840944582298169 Sin(x) Value: ('Sin(x)', 0.5411212521268758)
# X Value:-0.8443279255020151 Sin(x) Value: ('Sin(x)', 0.5358267949789965)
# X Value:-0.8476779360850834 Sin(x) Value: ('Sin(x)', 0.5305111843067339)
# X Value:-0.850994481794692 Sin(x) Value: ('Sin(x)', 0.5251746299612955)
# X Value:-0.8542774316992953 Sin(x) Value: ('Sin(x)', 0.5198173426207093)
# X Value:-0.8575266561936523 Sin(x) Value: ('Sin(x)', 0.5144395337815062)
# X Value:-0.8607420270039438 Sin(x) Value: ('Sin(x)', 0.509041415750371)
# X Value:-0.8639234171928353 Sin(x) Value: ('Sin(x)', 0.5036232016357609)
# X Value:-0.86707070116449 Sin(x) Value: ('Sin(x)', 0.49818510533949084)
# X Value:-0.8701837546695256 Sin(x) Value: ('Sin(x)', 0.4927273415482915)
# X Value:-0.8732624548099202 Sin(x) Value: ('Sin(x)', 0.4872501257253322)
# X Value:-0.8763066800438636 Sin(x) Value: ('Sin(x)', 0.48175367410171516)
# X Value:-0.8793163101905562 Sin(x) Value: ('Sin(x)', 0.47623820366793895)
# X Value:-0.8822912264349533 Sin(x) Value: ('Sin(x)', 0.47070393216533235)
# X Value:-0.8852313113324553 Sin(x) Value: ('Sin(x)', 0.4651510780774581)
# X Value:-0.8881364488135444 Sin(x) Value: ('Sin(x)', 0.459579860621488)
# X Value:-0.8910065241883677 Sin(x) Value: ('Sin(x)', 0.45399049973954686)
# X Value:-0.8938414241512637 Sin(x) Value: ('Sin(x)', 0.4483832160900323)
# X Value:-0.8966410367852358 Sin(x) Value: ('Sin(x)', 0.4427582310389015)
# X Value:-0.899405251566371 Sin(x) Value: ('Sin(x)', 0.4371157666509328)
# X Value:-0.9021339593682027 Sin(x) Value: ('Sin(x)', 0.43145604568095886)
# X Value:-0.9048270524660195 Sin(x) Value: ('Sin(x)', 0.4257792915650725)
# X Value:-0.9074844245411169 Sin(x) Value: ('Sin(x)', 0.420085728411806)
# X Value:-0.9101059706849957 Sin(x) Value: ('Sin(x)', 0.41437558099328387)
# X Value:-0.9126915874035026 Sin(x) Value: ('Sin(x)', 0.40864907473634915)
# X Value:-0.9152411726209174 Sin(x) Value: ('Sin(x)', 0.40290643571366275)
# X Value:-0.917754625683981 Sin(x) Value: ('Sin(x)', 0.3971478906347806)
# X Value:-0.9202318473658703 Sin(x) Value: ('Sin(x)', 0.39137366683720237)
# X Value:-0.9226727398701148 Sin(x) Value: ('Sin(x)', 0.3855839922773965)
# X Value:-0.925077206834458 Sin(x) Value: ('Sin(x)', 0.379779095521801)
# X Value:-0.9274451533346614 Sin(x) Value: ('Sin(x)', 0.3739592057378003)
# X Value:-0.9297764858882515 Sin(x) Value: ('Sin(x)', 0.36812455268467775)
# X Value:-0.9320711124582108 Sin(x) Value: ('Sin(x)', 0.36227536670454585)
# X Value:-0.934328942456612 Sin(x) Value: ('Sin(x)', 0.3564118787132508)
# X Value:-0.9365498867481923 Sin(x) Value: ('Sin(x)', 0.3505343201912591)
# X Value:-0.9387338576538741 Sin(x) Value: ('Sin(x)', 0.34464292317451706)
# X Value:-0.9408807689542256 Sin(x) Value: ('Sin(x)', 0.33873792024529137)
# X Value:-0.9429905358928646 Sin(x) Value: ('Sin(x)', 0.33281954452298657)
# X Value:-0.9450630751798049 Sin(x) Value: ('Sin(x)', 0.32688802965494235)
# X Value:-0.9470983049947445 Sin(x) Value: ('Sin(x)', 0.3209436098072093)
# X Value:-0.9490961449902948 Sin(x) Value: ('Sin(x)', 0.31498651965530455)
# X Value:-0.9510565162951536 Sin(x) Value: ('Sin(x)', 0.30901699437494756)
# X Value:-0.9529793415172189 Sin(x) Value: ('Sin(x)', 0.30303526963277405)
# X Value:-0.9548645447466431 Sin(x) Value: ('Sin(x)', 0.297041581577035)
# X Value:-0.9567120515588307 Sin(x) Value: ('Sin(x)', 0.2910361668282718)
# X Value:-0.9585217890173761 Sin(x) Value: ('Sin(x)', 0.28501926246997605)
# X Value:-0.9602936856769433 Sin(x) Value: ('Sin(x)', 0.2789911060392291)
# X Value:-0.9620276715860862 Sin(x) Value: ('Sin(x)', 0.27295193551732505)
# X Value:-0.9637236782900099 Sin(x) Value: ('Sin(x)', 0.26690198932037534)
# X Value:-0.965381638833274 Sin(x) Value: ('Sin(x)', 0.2608415062898971)
# X Value:-0.9670014877624352 Sin(x) Value: ('Sin(x)', 0.25477072568338227)
# X Value:-0.9685831611286313 Sin(x) Value: ('Sin(x)', 0.24868988716485485)
# X Value:-0.970126596490106 Sin(x) Value: ('Sin(x)', 0.24259923079540743)
# X Value:-0.9716317329146741 Sin(x) Value: ('Sin(x)', 0.23649899702372462)
# X Value:-0.9730985109821267 Sin(x) Value: ('Sin(x)', 0.2303894266765905)
# X Value:-0.9745268727865772 Sin(x) Value: ('Sin(x)', 0.22427076094938103)
# X Value:-0.9759167619387475 Sin(x) Value: ('Sin(x)', 0.21814324139654234)
# X Value:-0.9772681235681935 Sin(x) Value: ('Sin(x)', 0.2120071099220548)
# X Value:-0.9785809043254722 Sin(x) Value: ('Sin(x)', 0.20586260876988144)
# X Value:-0.979855052384247 Sin(x) Value: ('Sin(x)', 0.19970998051440708)
# X Value:-0.9810905174433342 Sin(x) Value: ('Sin(x)', 0.19354946805086026)
# X Value:-0.9822872507286886 Sin(x) Value: ('Sin(x)', 0.18738131458572457)
# X Value:-0.9834452049953297 Sin(x) Value: ('Sin(x)', 0.18120576362713725)
# X Value:-0.9845643345292054 Sin(x) Value: ('Sin(x)', 0.1750230589752759)
# X Value:-0.985644595148998 Sin(x) Value: ('Sin(x)', 0.16883344471273365)
# X Value:-0.986685944207868 Sin(x) Value: ('Sin(x)', 0.16263716519488333)
# X Value:-0.9876883405951377 Sin(x) Value: ('Sin(x)', 0.15643446504023098)
# X Value:-0.9886517447379138 Sin(x) Value: ('Sin(x)', 0.15022558912075712)
# X Value:-0.9895761186026508 Sin(x) Value: ('Sin(x)', 0.14401078255225216)
# X Value:-0.9904614256966511 Sin(x) Value: ('Sin(x)', 0.13779029068463802)
# X Value:-0.9913076310695064 Sin(x) Value: ('Sin(x)', 0.1315643590922824)
# X Value:-0.9921147013144777 Sin(x) Value: ('Sin(x)', 0.1253332335643041)
# X Value:-0.9928826045698135 Sin(x) Value: ('Sin(x)', 0.11909716009486955)
# X Value:-0.9936113105200083 Sin(x) Value: ('Sin(x)', 0.11285638487348144)
# X Value:-0.9943007903969987 Sin(x) Value: ('Sin(x)', 0.10661115427526005)
# X Value:-0.9949510169813 Sin(x) Value: ('Sin(x)', 0.10036171485121498)
# X Value:-0.9955619646030798 Sin(x) Value: ('Sin(x)', 0.09410831331851435)
# X Value:-0.9961336091431724 Sin(x) Value: ('Sin(x)', 0.08785119655074315)
# X Value:-0.9966659280340298 Sin(x) Value: ('Sin(x)', 0.08159061156815749)
# X Value:-0.9971589002606139 Sin(x) Value: ('Sin(x)', 0.0753268055279326)
# X Value:-0.9976125063612251 Sin(x) Value: ('Sin(x)', 0.06906002571440562)
# X Value:-0.9980267284282716 Sin(x) Value: ('Sin(x)', 0.06279051952931314)
# X Value:-0.9984015501089751 Sin(x) Value: ('Sin(x)', 0.05651853448202424)
# X Value:-0.9987369566060176 Sin(x) Value: ('Sin(x)', 0.05024431817976966)
# X Value:-0.9990329346781248 Sin(x) Value: ('Sin(x)', 0.04396811831786496)
# X Value:-0.9992894726405894 Sin(x) Value: ('Sin(x)', 0.03769018266993454)
# X Value:-0.9995065603657317 Sin(x) Value: ('Sin(x)', 0.03141075907812824)
# X Value:-0.9996841892833002 Sin(x) Value: ('Sin(x)', 0.02513009544333737)
# X Value:-0.9998223523808092 Sin(x) Value: ('Sin(x)', 0.018848439715408012)
# X Value:-0.9999210442038162 Sin(x) Value: ('Sin(x)', 0.012566039883352392)
# X Value:-0.9999802608561371 Sin(x) Value: ('Sin(x)', 0.006283143965558682)
# X Value:-1.0 Sin(x) Value: ('Sin(x)', 1.2246467991473532e-16)
# X Value:-0.9999802608561371 Sin(x) Value: ('Sin(x)', -0.006283143965558882)
# X Value:-0.9999210442038162 Sin(x) Value: ('Sin(x)', -0.01256603988335259)
# X Value:-0.9998223523808092 Sin(x) Value: ('Sin(x)', -0.018848439715408213)
# X Value:-0.9996841892833003 Sin(x) Value: ('Sin(x)', -0.02513009544333757)
# X Value:-0.9995065603657317 Sin(x) Value: ('Sin(x)', -0.03141075907812844)
# X Value:-0.9992894726405894 Sin(x) Value: ('Sin(x)', -0.037690182669934735)
# X Value:-0.9990329346781248 Sin(x) Value: ('Sin(x)', -0.04396811831786515)
# X Value:-0.9987369566060176 Sin(x) Value: ('Sin(x)', -0.05024431817976941)
# X Value:-0.998401550108975 Sin(x) Value: ('Sin(x)', -0.056518534482024436)
# X Value:-0.9980267284282717 Sin(x) Value: ('Sin(x)', -0.06279051952931333)
# X Value:-0.9976125063612251 Sin(x) Value: ('Sin(x)', -0.06906002571440581)
# X Value:-0.9971589002606138 Sin(x) Value: ('Sin(x)', -0.07532680552793279)
# X Value:-0.9966659280340299 Sin(x) Value: ('Sin(x)', -0.08159061156815768)
# X Value:-0.9961336091431724 Sin(x) Value: ('Sin(x)', -0.08785119655074335)
# X Value:-0.9955619646030798 Sin(x) Value: ('Sin(x)', -0.09410831331851455)
# X Value:-0.9949510169813 Sin(x) Value: ('Sin(x)', -0.10036171485121517)
# X Value:-0.9943007903969988 Sin(x) Value: ('Sin(x)', -0.10661115427525981)
# X Value:-0.9936113105200082 Sin(x) Value: ('Sin(x)', -0.11285638487348164)
# X Value:-0.9928826045698135 Sin(x) Value: ('Sin(x)', -0.11909716009486974)
# X Value:-0.9921147013144777 Sin(x) Value: ('Sin(x)', -0.1253332335643043)
# X Value:-0.9913076310695064 Sin(x) Value: ('Sin(x)', -0.13156435909228262)
# X Value:-0.9904614256966511 Sin(x) Value: ('Sin(x)', -0.13779029068463824)
# X Value:-0.9895761186026508 Sin(x) Value: ('Sin(x)', -0.1440107825522524)
# X Value:-0.988651744737914 Sin(x) Value: ('Sin(x)', -0.15022558912075734)
# X Value:-0.9876883405951377 Sin(x) Value: ('Sin(x)', -0.15643446504023076)
# X Value:-0.986685944207868 Sin(x) Value: ('Sin(x)', -0.16263716519488355)
# X Value:-0.9856445951489979 Sin(x) Value: ('Sin(x)', -0.16883344471273387)
# X Value:-0.9845643345292054 Sin(x) Value: ('Sin(x)', -0.17502305897527612)
# X Value:-0.9834452049953297 Sin(x) Value: ('Sin(x)', -0.18120576362713747)
# X Value:-0.9822872507286886 Sin(x) Value: ('Sin(x)', -0.1873813145857248)
# X Value:-0.9810905174433341 Sin(x) Value: ('Sin(x)', -0.19354946805086048)
# X Value:-0.979855052384247 Sin(x) Value: ('Sin(x)', -0.1997099805144073)
# X Value:-0.9785809043254722 Sin(x) Value: ('Sin(x)', -0.20586260876988122)
# X Value:-0.9772681235681936 Sin(x) Value: ('Sin(x)', -0.2120071099220546)
# X Value:-0.9759167619387475 Sin(x) Value: ('Sin(x)', -0.21814324139654256)
# X Value:-0.9745268727865772 Sin(x) Value: ('Sin(x)', -0.22427076094938123)
# X Value:-0.9730985109821266 Sin(x) Value: ('Sin(x)', -0.23038942667659068)
# X Value:-0.9716317329146741 Sin(x) Value: ('Sin(x)', -0.23649899702372484)
# X Value:-0.9701265964901059 Sin(x) Value: ('Sin(x)', -0.24259923079540763)
# X Value:-0.9685831611286312 Sin(x) Value: ('Sin(x)', -0.24868988716485504)
# X Value:-0.9670014877624351 Sin(x) Value: ('Sin(x)', -0.2547707256833825)
# X Value:-0.9653816388332741 Sin(x) Value: ('Sin(x)', -0.2608415062898969)
# X Value:-0.9637236782900099 Sin(x) Value: ('Sin(x)', -0.26690198932037557)
# X Value:-0.962027671586086 Sin(x) Value: ('Sin(x)', -0.2729519355173253)
# X Value:-0.9602936856769432 Sin(x) Value: ('Sin(x)', -0.27899110603922933)
# X Value:-0.9585217890173761 Sin(x) Value: ('Sin(x)', -0.2850192624699763)
# X Value:-0.9567120515588305 Sin(x) Value: ('Sin(x)', -0.29103616682827205)
# X Value:-0.954864544746643 Sin(x) Value: ('Sin(x)', -0.29704158157703514)
# X Value:-0.9529793415172189 Sin(x) Value: ('Sin(x)', -0.3030352696327743)
# X Value:-0.9510565162951538 Sin(x) Value: ('Sin(x)', -0.30901699437494734)
# X Value:-0.9490961449902947 Sin(x) Value: ('Sin(x)', -0.3149865196553048)
# X Value:-0.9470983049947443 Sin(x) Value: ('Sin(x)', -0.32094360980720954)
# X Value:-0.9450630751798049 Sin(x) Value: ('Sin(x)', -0.32688802965494257)
# X Value:-0.9429905358928645 Sin(x) Value: ('Sin(x)', -0.3328195445229868)
# X Value:-0.9408807689542255 Sin(x) Value: ('Sin(x)', -0.33873792024529153)
# X Value:-0.938733857653874 Sin(x) Value: ('Sin(x)', -0.3446429231745173)
# X Value:-0.9365498867481923 Sin(x) Value: ('Sin(x)', -0.3505343201912593)
# X Value:-0.9343289424566119 Sin(x) Value: ('Sin(x)', -0.35641187871325103)
# X Value:-0.932071112458211 Sin(x) Value: ('Sin(x)', -0.36227536670454563)
# X Value:-0.9297764858882513 Sin(x) Value: ('Sin(x)', -0.368124552684678)
# X Value:-0.9274451533346613 Sin(x) Value: ('Sin(x)', -0.3739592057378005)
# X Value:-0.9250772068344579 Sin(x) Value: ('Sin(x)', -0.3797790955218012)
# X Value:-0.9226727398701147 Sin(x) Value: ('Sin(x)', -0.3855839922773967)
# X Value:-0.9202318473658702 Sin(x) Value: ('Sin(x)', -0.3913736668372026)
# X Value:-0.9177546256839809 Sin(x) Value: ('Sin(x)', -0.39714789063478084)
# X Value:-0.9152411726209173 Sin(x) Value: ('Sin(x)', -0.4029064357136629)
# X Value:-0.9126915874035028 Sin(x) Value: ('Sin(x)', -0.408649074736349)
# X Value:-0.9101059706849957 Sin(x) Value: ('Sin(x)', -0.4143755809932841)
# X Value:-0.9074844245411168 Sin(x) Value: ('Sin(x)', -0.42008572841180625)
# X Value:-0.9048270524660194 Sin(x) Value: ('Sin(x)', -0.4257792915650727)
# X Value:-0.9021339593682026 Sin(x) Value: ('Sin(x)', -0.4314560456809591)
# X Value:-0.8994052515663709 Sin(x) Value: ('Sin(x)', -0.43711576665093305)
# X Value:-0.8966410367852357 Sin(x) Value: ('Sin(x)', -0.4427582310389017)
# X Value:-0.8938414241512636 Sin(x) Value: ('Sin(x)', -0.44838321609003245)
# X Value:-0.8910065241883678 Sin(x) Value: ('Sin(x)', -0.45399049973954664)
# X Value:-0.8881364488135445 Sin(x) Value: ('Sin(x)', -0.45957986062148776)
# X Value:-0.8852313113324551 Sin(x) Value: ('Sin(x)', -0.4651510780774583)
# X Value:-0.8822912264349532 Sin(x) Value: ('Sin(x)', -0.4707039321653326)
# X Value:-0.8793163101905561 Sin(x) Value: ('Sin(x)', -0.4762382036679392)
# X Value:-0.8763066800438635 Sin(x) Value: ('Sin(x)', -0.4817536741017154)
# X Value:-0.87326245480992 Sin(x) Value: ('Sin(x)', -0.48725012572533244)
# X Value:-0.8701837546695255 Sin(x) Value: ('Sin(x)', -0.49272734154829173)
# X Value:-0.8670707011644898 Sin(x) Value: ('Sin(x)', -0.49818510533949106)
# X Value:-0.8639234171928354 Sin(x) Value: ('Sin(x)', -0.5036232016357607)
# X Value:-0.8607420270039436 Sin(x) Value: ('Sin(x)', -0.5090414157503712)
# X Value:-0.8575266561936522 Sin(x) Value: ('Sin(x)', -0.5144395337815064)
# X Value:-0.8542774316992952 Sin(x) Value: ('Sin(x)', -0.5198173426207094)
# X Value:-0.8509944817946918 Sin(x) Value: ('Sin(x)', -0.5251746299612957)
# X Value:-0.8476779360850831 Sin(x) Value: ('Sin(x)', -0.5305111843067342)
# X Value:-0.844327925502015 Sin(x) Value: ('Sin(x)', -0.5358267949789968)
# X Value:-0.8409445822981689 Sin(x) Value: ('Sin(x)', -0.541121252126876)
# X Value:-0.8375280400421418 Sin(x) Value: ('Sin(x)', -0.5463943467342689)
# X Value:-0.8340784336131712 Sin(x) Value: ('Sin(x)', -0.5516458706284301)
# X Value:-0.8305958991958127 Sin(x) Value: ('Sin(x)', -0.556875616488188)
# X Value:-0.8270805742745618 Sin(x) Value: ('Sin(x)', -0.5620833778521306)
# X Value:-0.8235325976284275 Sin(x) Value: ('Sin(x)', -0.5672689491267565)
# X Value:-0.8199521093254524 Sin(x) Value: ('Sin(x)', -0.5724321255945909)
# X Value:-0.8163392507171839 Sin(x) Value: ('Sin(x)', -0.5775727034222676)
# X Value:-0.812694164433094 Sin(x) Value: ('Sin(x)', -0.5826904796685762)
# X Value:-0.8090169943749473 Sin(x) Value: ('Sin(x)', -0.5877852522924732)
# X Value:-0.8053078857111221 Sin(x) Value: ('Sin(x)', -0.5928568201610591)
# X Value:-0.8015669848708767 Sin(x) Value: ('Sin(x)', -0.5979049830575188)
# X Value:-0.7977944395385711 Sin(x) Value: ('Sin(x)', -0.6029295416890247)
# X Value:-0.7939903986478354 Sin(x) Value: ('Sin(x)', -0.6079302976946054)
# X Value:-0.7901550123756904 Sin(x) Value: ('Sin(x)', -0.6129070536529765)
# X Value:-0.7862884321366189 Sin(x) Value: ('Sin(x)', -0.6178596130903344)
# X Value:-0.7823908105765881 Sin(x) Value: ('Sin(x)', -0.6227877804881127)
# X Value:-0.7784623015670233 Sin(x) Value: ('Sin(x)', -0.6276913612907007)
# X Value:-0.774503060198734 Sin(x) Value: ('Sin(x)', -0.6325701619131243)
# X Value:-0.7705132427757894 Sin(x) Value: ('Sin(x)', -0.6374239897486896)
# X Value:-0.76649300680935 Sin(x) Value: ('Sin(x)', -0.6422526531765843)
# X Value:-0.762442511011448 Sin(x) Value: ('Sin(x)', -0.6470559615694443)
# X Value:-0.7583619152887219 Sin(x) Value: ('Sin(x)', -0.6518337253008788)
# X Value:-0.7542513807361039 Sin(x) Value: ('Sin(x)', -0.6565857557529565)
# X Value:-0.7501110696304596 Sin(x) Value: ('Sin(x)', -0.661311865323652)
# X Value:-0.7459411454241821 Sin(x) Value: ('Sin(x)', -0.6660118674342518)
# X Value:-0.7417417727387394 Sin(x) Value: ('Sin(x)', -0.6706855765367199)
# X Value:-0.737513117358174 Sin(x) Value: ('Sin(x)', -0.6753328081210244)
# X Value:-0.7332553462225602 Sin(x) Value: ('Sin(x)', -0.6799533787224192)
# X Value:-0.7289686274214117 Sin(x) Value: ('Sin(x)', -0.6845471059286887)
# X Value:-0.7246531301870467 Sin(x) Value: ('Sin(x)', -0.6891138083873486)
# X Value:-0.7203090248879069 Sin(x) Value: ('Sin(x)', -0.693653305812805)
# X Value:-0.7159364830218311 Sin(x) Value: ('Sin(x)', -0.6981654189934728)
# X Value:-0.7115356772092852 Sin(x) Value: ('Sin(x)', -0.7026499697988494)
# X Value:-0.7071067811865474 Sin(x) Value: ('Sin(x)', -0.7071067811865478)
# X Value:-0.7026499697988493 Sin(x) Value: ('Sin(x)', -0.7115356772092853)
# X Value:-0.6981654189934727 Sin(x) Value: ('Sin(x)', -0.7159364830218312)
# X Value:-0.693653305812805 Sin(x) Value: ('Sin(x)', -0.7203090248879069)
# X Value:-0.6891138083873485 Sin(x) Value: ('Sin(x)', -0.7246531301870468)
# X Value:-0.6845471059286886 Sin(x) Value: ('Sin(x)', -0.7289686274214117)
# X Value:-0.6799533787224191 Sin(x) Value: ('Sin(x)', -0.7332553462225603)
# X Value:-0.6753328081210243 Sin(x) Value: ('Sin(x)', -0.7375131173581742)
# X Value:-0.6706855765367199 Sin(x) Value: ('Sin(x)', -0.7417417727387395)
# X Value:-0.6660118674342517 Sin(x) Value: ('Sin(x)', -0.7459411454241822)
# X Value:-0.6613118653236519 Sin(x) Value: ('Sin(x)', -0.7501110696304596)
# X Value:-0.6565857557529564 Sin(x) Value: ('Sin(x)', -0.754251380736104)
# X Value:-0.6518337253008784 Sin(x) Value: ('Sin(x)', -0.7583619152887223)
# X Value:-0.6470559615694442 Sin(x) Value: ('Sin(x)', -0.7624425110114481)
# X Value:-0.6422526531765845 Sin(x) Value: ('Sin(x)', -0.7664930068093497)
# X Value:-0.6374239897486895 Sin(x) Value: ('Sin(x)', -0.7705132427757895)
# X Value:-0.6325701619131245 Sin(x) Value: ('Sin(x)', -0.7745030601987338)
# X Value:-0.6276913612907002 Sin(x) Value: ('Sin(x)', -0.7784623015670238)
# X Value:-0.6227877804881126 Sin(x) Value: ('Sin(x)', -0.7823908105765882)
# X Value:-0.617859613090334 Sin(x) Value: ('Sin(x)', -0.7862884321366193)
# X Value:-0.6129070536529764 Sin(x) Value: ('Sin(x)', -0.7901550123756905)
# X Value:-0.6079302976946049 Sin(x) Value: ('Sin(x)', -0.7939903986478358)
# X Value:-0.6029295416890246 Sin(x) Value: ('Sin(x)', -0.7977944395385712)
# X Value:-0.597904983057519 Sin(x) Value: ('Sin(x)', -0.8015669848708765)
# X Value:-0.592856820161059 Sin(x) Value: ('Sin(x)', -0.8053078857111222)
# X Value:-0.5877852522924732 Sin(x) Value: ('Sin(x)', -0.8090169943749475)
# X Value:-0.5826904796685758 Sin(x) Value: ('Sin(x)', -0.8126941644330943)
# X Value:-0.5775727034222676 Sin(x) Value: ('Sin(x)', -0.816339250717184)
# X Value:-0.5724321255945904 Sin(x) Value: ('Sin(x)', -0.8199521093254527)
# X Value:-0.5672689491267564 Sin(x) Value: ('Sin(x)', -0.8235325976284276)
# X Value:-0.5620833778521308 Sin(x) Value: ('Sin(x)', -0.8270805742745617)
# X Value:-0.5568756164881878 Sin(x) Value: ('Sin(x)', -0.8305958991958128)
# ...
# X Value:0.19970998051440678 Sin(x) Value: ('Sin(x)', -0.979855052384247)
# X Value:0.20586260876988158 Sin(x) Value: ('Sin(x)', -0.9785809043254722)
# X Value:0.21200710992205452 Sin(x) Value: ('Sin(x)', -0.9772681235681936)
# X Value:0.2181432413965429 Sin(x) Value: ('Sin(x)', -0.9759167619387475)
# X Value:0.22427076094938117 Sin(x) Value: ('Sin(x)', -0.9745268727865772)
# X Value:0.23038942667659104 Sin(x) Value: ('Sin(x)', -0.9730985109821265)
# X Value:0.23649899702372476 Sin(x) Value: ('Sin(x)', -0.9716317329146741)
# X Value:0.24259923079540713 Sin(x) Value: ('Sin(x)', -0.9701265964901061)
# X Value:0.248689887164855 Sin(x) Value: ('Sin(x)', -0.9685831611286312)
# X Value:0.254770725683382 Sin(x) Value: ('Sin(x)', -0.9670014877624352)
# X Value:0.2608415062898973 Sin(x) Value: ('Sin(x)', -0.965381638833274)
# X Value:0.2669019893203755 Sin(x) Value: ('Sin(x)', -0.9637236782900099)
# X Value:0.27295193551732566 Sin(x) Value: ('Sin(x)', -0.9620276715860859)
# X Value:0.2789911060392293 Sin(x) Value: ('Sin(x)', -0.9602936856769432)
# X Value:0.28501926246997666 Sin(x) Value: ('Sin(x)', -0.9585217890173758)
# X Value:0.291036166828272 Sin(x) Value: ('Sin(x)', -0.9567120515588305)
# X Value:0.2970415815770347 Sin(x) Value: ('Sin(x)', -0.9548645447466432)
# X Value:0.3030352696327742 Sin(x) Value: ('Sin(x)', -0.9529793415172189)
# X Value:0.3090169943749473 Sin(x) Value: ('Sin(x)', -0.9510565162951538)
# X Value:0.31498651965530516 Sin(x) Value: ('Sin(x)', -0.9490961449902946)
# X Value:0.3209436098072095 Sin(x) Value: ('Sin(x)', -0.9470983049947443)
# X Value:0.3268880296549429 Sin(x) Value: ('Sin(x)', -0.9450630751798047)
# X Value:0.33281954452298673 Sin(x) Value: ('Sin(x)', -0.9429905358928645)
# X Value:0.3387379202452919 Sin(x) Value: ('Sin(x)', -0.9408807689542253)
# X Value:0.3446429231745172 Sin(x) Value: ('Sin(x)', -0.9387338576538741)
# X Value:0.3505343201912588 Sin(x) Value: ('Sin(x)', -0.9365498867481924)
# X Value:0.356411878713251 Sin(x) Value: ('Sin(x)', -0.9343289424566119)
# X Value:0.3622753667045456 Sin(x) Value: ('Sin(x)', -0.932071112458211)
# X Value:0.3681245526846783 Sin(x) Value: ('Sin(x)', -0.9297764858882512)
# X Value:0.37395920573780045 Sin(x) Value: ('Sin(x)', -0.9274451533346613)
# X Value:0.37977909552180156 Sin(x) Value: ('Sin(x)', -0.9250772068344578)
# X Value:0.38558399227739665 Sin(x) Value: ('Sin(x)', -0.9226727398701147)
# X Value:0.391373666837203 Sin(x) Value: ('Sin(x)', -0.92023184736587)
# X Value:0.3971478906347808 Sin(x) Value: ('Sin(x)', -0.917754625683981)
# X Value:0.40290643571366247 Sin(x) Value: ('Sin(x)', -0.9152411726209175)
# X Value:0.4086490747363493 Sin(x) Value: ('Sin(x)', -0.9126915874035025)
# X Value:0.41437558099328403 Sin(x) Value: ('Sin(x)', -0.9101059706849957)
# X Value:0.4200857284118066 Sin(x) Value: ('Sin(x)', -0.9074844245411167)
# X Value:0.42577929156507266 Sin(x) Value: ('Sin(x)', -0.9048270524660195)
# X Value:0.4314560456809594 Sin(x) Value: ('Sin(x)', -0.9021339593682025)
# X Value:0.437115766650933 Sin(x) Value: ('Sin(x)', -0.8994052515663709)
# X Value:0.4427582310389013 Sin(x) Value: ('Sin(x)', -0.8966410367852359)
# X Value:0.4483832160900324 Sin(x) Value: ('Sin(x)', -0.8938414241512636)
# X Value:0.4539904997395466 Sin(x) Value: ('Sin(x)', -0.8910065241883678)
# X Value:0.4595798606214881 Sin(x) Value: ('Sin(x)', -0.8881364488135443)
# X Value:0.46515107807745826 Sin(x) Value: ('Sin(x)', -0.8852313113324551)
# X Value:0.4707039321653329 Sin(x) Value: ('Sin(x)', -0.882291226434953)
# X Value:0.4762382036679391 Sin(x) Value: ('Sin(x)', -0.8793163101905561)
# X Value:0.48175367410171566 Sin(x) Value: ('Sin(x)', -0.8763066800438633)
# X Value:0.48725012572533233 Sin(x) Value: ('Sin(x)', -0.87326245480992)
# X Value:0.49272734154829123 Sin(x) Value: ('Sin(x)', -0.8701837546695257)
# X Value:0.49818510533949095 Sin(x) Value: ('Sin(x)', -0.8670707011644899)
# X Value:0.5036232016357606 Sin(x) Value: ('Sin(x)', -0.8639234171928354)
# X Value:0.5090414157503715 Sin(x) Value: ('Sin(x)', -0.8607420270039434)
# X Value:0.5144395337815063 Sin(x) Value: ('Sin(x)', -0.8575266561936522)
# X Value:0.5198173426207098 Sin(x) Value: ('Sin(x)', -0.8542774316992949)
# X Value:0.5251746299612956 Sin(x) Value: ('Sin(x)', -0.8509944817946918)
# X Value:0.5305111843067344 Sin(x) Value: ('Sin(x)', -0.8476779360850829)
# X Value:0.5358267949789967 Sin(x) Value: ('Sin(x)', -0.844327925502015)
# X Value:0.5411212521268756 Sin(x) Value: ('Sin(x)', -0.8409445822981692)
# X Value:0.5463943467342692 Sin(x) Value: ('Sin(x)', -0.8375280400421415)
# X Value:0.55164587062843 Sin(x) Value: ('Sin(x)', -0.8340784336131712)
# X Value:0.5568756164881882 Sin(x) Value: ('Sin(x)', -0.8305958991958124)
# X Value:0.5620833778521305 Sin(x) Value: ('Sin(x)', -0.8270805742745619)
# X Value:0.5672689491267567 Sin(x) Value: ('Sin(x)', -0.8235325976284272)
# X Value:0.5724321255945908 Sin(x) Value: ('Sin(x)', -0.8199521093254524)
# X Value:0.5775727034222672 Sin(x) Value: ('Sin(x)', -0.8163392507171842)
# X Value:0.5826904796685761 Sin(x) Value: ('Sin(x)', -0.812694164433094)
# X Value:0.5877852522924728 Sin(x) Value: ('Sin(x)', -0.8090169943749477)
# X Value:0.5928568201610593 Sin(x) Value: ('Sin(x)', -0.8053078857111219)
# X Value:0.5979049830575187 Sin(x) Value: ('Sin(x)', -0.8015669848708767)
# X Value:0.6029295416890249 Sin(x) Value: ('Sin(x)', -0.7977944395385709)
# X Value:0.6079302976946053 Sin(x) Value: ('Sin(x)', -0.7939903986478354)
# X Value:0.6129070536529768 Sin(x) Value: ('Sin(x)', -0.7901550123756902)
# X Value:0.6178596130903343 Sin(x) Value: ('Sin(x)', -0.7862884321366189)
# X Value:0.6227877804881122 Sin(x) Value: ('Sin(x)', -0.7823908105765884)
# X Value:0.6276913612907006 Sin(x) Value: ('Sin(x)', -0.7784623015670233)
# X Value:0.6325701619131242 Sin(x) Value: ('Sin(x)', -0.774503060198734)
# X Value:0.6374239897486899 Sin(x) Value: ('Sin(x)', -0.7705132427757891)
# X Value:0.6422526531765842 Sin(x) Value: ('Sin(x)', -0.76649300680935)
# X Value:0.6470559615694446 Sin(x) Value: ('Sin(x)', -0.7624425110114477)
# X Value:0.6518337253008787 Sin(x) Value: ('Sin(x)', -0.7583619152887219)
# X Value:0.6565857557529567 Sin(x) Value: ('Sin(x)', -0.7542513807361035)
# X Value:0.6613118653236519 Sin(x) Value: ('Sin(x)', -0.7501110696304596)
# X Value:0.6660118674342514 Sin(x) Value: ('Sin(x)', -0.7459411454241824)
# X Value:0.6706855765367202 Sin(x) Value: ('Sin(x)', -0.7417417727387391)
# X Value:0.6753328081210243 Sin(x) Value: ('Sin(x)', -0.737513117358174)
# X Value:0.6799533787224195 Sin(x) Value: ('Sin(x)', -0.7332553462225598)
# X Value:0.6845471059286886 Sin(x) Value: ('Sin(x)', -0.7289686274214117)
# X Value:0.6891138083873488 Sin(x) Value: ('Sin(x)', -0.7246531301870464)
# X Value:0.693653305812805 Sin(x) Value: ('Sin(x)', -0.7203090248879069)
# X Value:0.6981654189934725 Sin(x) Value: ('Sin(x)', -0.7159364830218314)
# X Value:0.7026499697988493 Sin(x) Value: ('Sin(x)', -0.7115356772092852)
# X Value:0.7071067811865474 Sin(x) Value: ('Sin(x)', -0.7071067811865477)
# X Value:0.7115356772092856 Sin(x) Value: ('Sin(x)', -0.7026499697988491)
# X Value:0.7159364830218311 Sin(x) Value: ('Sin(x)', -0.6981654189934727)
# X Value:0.7203090248879072 Sin(x) Value: ('Sin(x)', -0.6936533058128047)
# X Value:0.7246531301870467 Sin(x) Value: ('Sin(x)', -0.6891138083873485)
# X Value:0.7289686274214119 Sin(x) Value: ('Sin(x)', -0.6845471059286883)
# X Value:0.7332553462225602 Sin(x) Value: ('Sin(x)', -0.6799533787224191)
# X Value:0.7375131173581738 Sin(x) Value: ('Sin(x)', -0.6753328081210247)
# X Value:0.7417417727387394 Sin(x) Value: ('Sin(x)', -0.6706855765367199)
# X Value:0.7459411454241821 Sin(x) Value: ('Sin(x)', -0.6660118674342518)
# X Value:0.7501110696304598 Sin(x) Value: ('Sin(x)', -0.6613118653236516)
# X Value:0.7542513807361039 Sin(x) Value: ('Sin(x)', -0.6565857557529564)
# X Value:0.7583619152887222 Sin(x) Value: ('Sin(x)', -0.6518337253008784)
# X Value:0.762442511011448 Sin(x) Value: ('Sin(x)', -0.6470559615694442)
# X Value:0.7664930068093503 Sin(x) Value: ('Sin(x)', -0.6422526531765839)
# X Value:0.7705132427757894 Sin(x) Value: ('Sin(x)', -0.6374239897486895)
# X Value:0.7745030601987337 Sin(x) Value: ('Sin(x)', -0.6325701619131245)
# X Value:0.7784623015670237 Sin(x) Value: ('Sin(x)', -0.6276913612907002)
# X Value:0.7823908105765881 Sin(x) Value: ('Sin(x)', -0.6227877804881126)
# X Value:0.7862884321366193 Sin(x) Value: ('Sin(x)', -0.617859613090334)
# X Value:0.7901550123756904 Sin(x) Value: ('Sin(x)', -0.6129070536529765)
# X Value:0.7939903986478357 Sin(x) Value: ('Sin(x)', -0.6079302976946049)
# X Value:0.7977944395385711 Sin(x) Value: ('Sin(x)', -0.6029295416890246)
# X Value:0.801566984870877 Sin(x) Value: ('Sin(x)', -0.5979049830575184)
# X Value:0.8053078857111221 Sin(x) Value: ('Sin(x)', -0.592856820161059)
# X Value:0.8090169943749473 Sin(x) Value: ('Sin(x)', -0.5877852522924732)
# X Value:0.8126941644330942 Sin(x) Value: ('Sin(x)', -0.5826904796685758)
# X Value:0.8163392507171839 Sin(x) Value: ('Sin(x)', -0.5775727034222676)
# X Value:0.8199521093254526 Sin(x) Value: ('Sin(x)', -0.5724321255945904)
# X Value:0.8235325976284275 Sin(x) Value: ('Sin(x)', -0.5672689491267564)
# X Value:0.8270805742745622 Sin(x) Value: ('Sin(x)', -0.5620833778521301)
# X Value:0.8305958991958127 Sin(x) Value: ('Sin(x)', -0.5568756164881878)
# X Value:0.834078433613171 Sin(x) Value: ('Sin(x)', -0.5516458706284304)
# X Value:0.8375280400421418 Sin(x) Value: ('Sin(x)', -0.5463943467342688)
# X Value:0.8409445822981689 Sin(x) Value: ('Sin(x)', -0.5411212521268759)
# X Value:0.8443279255020153 Sin(x) Value: ('Sin(x)', -0.5358267949789962)
# X Value:0.8476779360850831 Sin(x) Value: ('Sin(x)', -0.530511184306734)
# X Value:0.8509944817946921 Sin(x) Value: ('Sin(x)', -0.5251746299612953)
# X Value:0.8542774316992952 Sin(x) Value: ('Sin(x)', -0.5198173426207093)
# X Value:0.8575266561936524 Sin(x) Value: ('Sin(x)', -0.5144395337815059)
# X Value:0.8607420270039436 Sin(x) Value: ('Sin(x)', -0.5090414157503711)
# X Value:0.863923417192835 Sin(x) Value: ('Sin(x)', -0.503623201635761)
# X Value:0.8670707011644901 Sin(x) Value: ('Sin(x)', -0.49818510533949056)
# X Value:0.8701837546695255 Sin(x) Value: ('Sin(x)', -0.4927273415482916)
# X Value:0.8732624548099203 Sin(x) Value: ('Sin(x)', -0.48725012572533194)
# X Value:0.8763066800438635 Sin(x) Value: ('Sin(x)', -0.48175367410171527)
# X Value:0.8793163101905563 Sin(x) Value: ('Sin(x)', -0.4762382036679387)
# X Value:0.8822912264349532 Sin(x) Value: ('Sin(x)', -0.47070393216533246)
# X Value:0.8852313113324553 Sin(x) Value: ('Sin(x)', -0.4651510780774578)
# X Value:0.8881364488135445 Sin(x) Value: ('Sin(x)', -0.45957986062148765)
# X Value:0.8910065241883676 Sin(x) Value: ('Sin(x)', -0.45399049973954697)
# X Value:0.8938414241512638 Sin(x) Value: ('Sin(x)', -0.44838321609003196)
# X Value:0.8966410367852357 Sin(x) Value: ('Sin(x)', -0.4427582310389016)
# X Value:0.8994052515663711 Sin(x) Value: ('Sin(x)', -0.43711576665093255)
# X Value:0.9021339593682026 Sin(x) Value: ('Sin(x)', -0.43145604568095897)
# X Value:0.9048270524660196 Sin(x) Value: ('Sin(x)', -0.4257792915650722)
# X Value:0.9074844245411168 Sin(x) Value: ('Sin(x)', -0.42008572841180614)
# X Value:0.9101059706849953 Sin(x) Value: ('Sin(x)', -0.4143755809932844)
# X Value:0.9126915874035028 Sin(x) Value: ('Sin(x)', -0.40864907473634887)
# X Value:0.9152411726209173 Sin(x) Value: ('Sin(x)', -0.40290643571366286)
# X Value:0.9177546256839811 Sin(x) Value: ('Sin(x)', -0.39714789063478034)
# X Value:0.9202318473658702 Sin(x) Value: ('Sin(x)', -0.3913736668372025)
# X Value:0.9226727398701149 Sin(x) Value: ('Sin(x)', -0.38558399227739615)
# X Value:0.9250772068344579 Sin(x) Value: ('Sin(x)', -0.3797790955218011)
# X Value:0.9274451533346614 Sin(x) Value: ('Sin(x)', -0.37395920573779995)
# X Value:0.9297764858882513 Sin(x) Value: ('Sin(x)', -0.36812455268467786)
# X Value:0.9320711124582108 Sin(x) Value: ('Sin(x)', -0.36227536670454596)
# X Value:0.934328942456612 Sin(x) Value: ('Sin(x)', -0.35641187871325053)
# X Value:0.9365498867481923 Sin(x) Value: ('Sin(x)', -0.3505343201912592)
# X Value:0.9387338576538742 Sin(x) Value: ('Sin(x)', -0.3446429231745168)
# X Value:0.9408807689542255 Sin(x) Value: ('Sin(x)', -0.3387379202452915)
# X Value:0.9429905358928646 Sin(x) Value: ('Sin(x)', -0.33281954452298623)
# X Value:0.9450630751798049 Sin(x) Value: ('Sin(x)', -0.32688802965494246)
# X Value:0.9470983049947446 Sin(x) Value: ('Sin(x)', -0.320943609807209)
# X Value:0.9490961449902947 Sin(x) Value: ('Sin(x)', -0.31498651965530466)
# X Value:0.9510565162951535 Sin(x) Value: ('Sin(x)', -0.3090169943749477)
# X Value:0.952979341517219 Sin(x) Value: ('Sin(x)', -0.3030352696327737)
# X Value:0.954864544746643 Sin(x) Value: ('Sin(x)', -0.29704158157703503)
# X Value:0.9567120515588308 Sin(x) Value: ('Sin(x)', -0.2910361668282715)
# X Value:0.9585217890173761 Sin(x) Value: ('Sin(x)', -0.28501926246997616)
# X Value:0.9602936856769433 Sin(x) Value: ('Sin(x)', -0.27899110603922883)
# X Value:0.962027671586086 Sin(x) Value: ('Sin(x)', -0.27295193551732516)
# X Value:0.9637236782900098 Sin(x) Value: ('Sin(x)', -0.2669019893203759)
# X Value:0.9653816388332741 Sin(x) Value: ('Sin(x)', -0.2608415062898968)
# X Value:0.9670014877624351 Sin(x) Value: ('Sin(x)', -0.2547707256833824)
# X Value:0.9685831611286313 Sin(x) Value: ('Sin(x)', -0.24868988716485452)
# X Value:0.9701265964901059 Sin(x) Value: ('Sin(x)', -0.24259923079540757)
# X Value:0.9716317329146742 Sin(x) Value: ('Sin(x)', -0.23649899702372434)
# X Value:0.9730985109821266 Sin(x) Value: ('Sin(x)', -0.23038942667659063)
# X Value:0.9745268727865773 Sin(x) Value: ('Sin(x)', -0.22427076094938073)
# X Value:0.9759167619387475 Sin(x) Value: ('Sin(x)', -0.21814324139654248)
# X Value:0.9772681235681935 Sin(x) Value: ('Sin(x)', -0.21200710992205493)
# X Value:0.9785809043254722 Sin(x) Value: ('Sin(x)', -0.20586260876988113)
# X Value:0.979855052384247 Sin(x) Value: ('Sin(x)', -0.19970998051440722)
# X Value:0.9810905174433342 Sin(x) Value: ('Sin(x)', -0.19354946805085996)
# X Value:0.9822872507286886 Sin(x) Value: ('Sin(x)', -0.1873813145857247)
# X Value:0.9834452049953297 Sin(x) Value: ('Sin(x)', -0.18120576362713695)
# X Value:0.9845643345292054 Sin(x) Value: ('Sin(x)', -0.17502305897527604)
# X Value:0.985644595148998 Sin(x) Value: ('Sin(x)', -0.16883344471273337)
# X Value:0.986685944207868 Sin(x) Value: ('Sin(x)', -0.16263716519488347)
# X Value:0.9876883405951375 Sin(x) Value: ('Sin(x)', -0.15643446504023112)
# X Value:0.988651744737914 Sin(x) Value: ('Sin(x)', -0.15022558912075681)
# X Value:0.9895761186026508 Sin(x) Value: ('Sin(x)', -0.1440107825522523)
# X Value:0.9904614256966512 Sin(x) Value: ('Sin(x)', -0.13779029068463772)
# X Value:0.9913076310695064 Sin(x) Value: ('Sin(x)', -0.13156435909228253)
# X Value:0.9921147013144777 Sin(x) Value: ('Sin(x)', -0.1253332335643038)
# X Value:0.9928826045698135 Sin(x) Value: ('Sin(x)', -0.11909716009486968)
# X Value:0.9936113105200083 Sin(x) Value: ('Sin(x)', -0.11285638487348112)
# X Value:0.9943007903969988 Sin(x) Value: ('Sin(x)', -0.10661115427525975)
# X Value:0.9949510169813 Sin(x) Value: ('Sin(x)', -0.1003617148512151)
# X Value:0.9955619646030799 Sin(x) Value: ('Sin(x)', -0.09410831331851403)
# X Value:0.9961336091431724 Sin(x) Value: ('Sin(x)', -0.08785119655074328)
# X Value:0.9966659280340299 Sin(x) Value: ('Sin(x)', -0.08159061156815717)
# X Value:0.9971589002606138 Sin(x) Value: ('Sin(x)', -0.07532680552793272)
# X Value:0.9976125063612252 Sin(x) Value: ('Sin(x)', -0.06906002571440531)
# X Value:0.9980267284282717 Sin(x) Value: ('Sin(x)', -0.06279051952931326)
# X Value:0.9984015501089751 Sin(x) Value: ('Sin(x)', -0.056518534482024804)
# X Value:0.9987369566060176 Sin(x) Value: ('Sin(x)', -0.050244318179769334)
# X Value:0.9990329346781248 Sin(x) Value: ('Sin(x)', -0.043968118317865075)
# X Value:0.9992894726405893 Sin(x) Value: ('Sin(x)', -0.037690182669934215)
# X Value:0.9995065603657317 Sin(x) Value: ('Sin(x)', -0.03141075907812836)
# X Value:0.9996841892833003 Sin(x) Value: ('Sin(x)', -0.02513009544333705)
# X Value:0.9998223523808092 Sin(x) Value: ('Sin(x)', -0.018848439715408137)
# X Value:0.9999210442038163 Sin(x) Value: ('Sin(x)', -0.01256603988335207)
# X Value:0.9999802608561371 Sin(x) Value: ('Sin(x)', -0.0062831439655588045)

# %% [markdown]
# I created the main function so that i could print out my sin and cos things so its chill like that

# %%
for i in range(11):
    print(f"X: {x[i]} Sin(X): {Sin(x[i])} Cos(X): {Cos(x[i])}")
# Out:
# X: 0.0 Sin(X): 0.0 Cos(X): 1.0
# X: 0.006283185307179587 Sin(X): 0.006283143965558951 Cos(X): 0.9999802608561372
# X: 0.012566370614359173 Sin(X): 0.012566039883352607 Cos(X): 0.9999210442038163
# X: 0.01884955592153876 Sin(X): 0.018848439715408175 Cos(X): 0.9998223523808092
# X: 0.025132741228718346 Sin(X): 0.02513009544333748 Cos(X): 0.9996841892833003
# X: 0.031415926535897934 Sin(X): 0.0314107590781283 Cos(X): 0.9995065603657317
# X: 0.03769911184307752 Sin(X): 0.03769018266993454 Cos(X): 0.9992894726405894
# X: 0.04398229715025711 Sin(X): 0.04396811831786491 Cos(X): 0.9990329346781248
# X: 0.05026548245743669 Sin(X): 0.050244318179769556 Cos(X): 0.9987369566060176
# X: 0.05654866776461628 Sin(X): 0.05651853448202453 Cos(X): 0.9984015501089751
# X: 0.06283185307179587 Sin(X): 0.06279051952931337 Cos(X): 0.9980267284282716

# %% [markdown]
# For loop that prints out the x, sin, cos values the first 10.
